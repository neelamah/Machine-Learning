# %% [markdown]
# #we need to provide K valus
# #K valuse can be chosse using grid search  or cross validation
# # to reduce complexcity we use :-
# KD tree->  it create binary tree for search. It use mean value.
# and Ball tree -> we used to  near points.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

#createing data
X, y = make_classification(
    n_samples=1000, # 1000 observations 
    n_features=3, # 3 total features
     n_redundant=1,
    n_classes=2, # binary target/label 
    random_state=999 
)

X
# Out:
# array([[-0.33504974,  0.02852654,  1.16193084],
#        [-1.37746253, -0.4058213 ,  0.44359618],
#        [-1.04520026, -0.72334759, -3.10470423],
#        ...,
#        [-0.75602574, -0.51816111, -2.20382324],
#        [ 0.56066316, -0.07335845, -2.15660348],
#        [-1.87521902, -1.11380394, -4.04620773]], shape=(1000, 3))

# %%
#split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

#create model
# we need to provide K valus
#K valuse can be chosse using grid search  or cross validation
classifier=KNeighborsClassifier(n_neighbors=5,algorithm='auto')

#train model
classifier.fit(X_train,y_train)

#predit data
y_pred=classifier.predict(X_test)

# metrics
print(confusion_matrix(y_pred,y_test))
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# [[158  20]
#  [ 11 141]]
# 0.906060606060606
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       178
#            1       0.88      0.93      0.90       152
#
#     accuracy                           0.91       330
#    macro avg       0.91      0.91      0.91       330
# weighted avg       0.91      0.91      0.91       330

# %% [markdown]
# ## KNN Regressor

# %%
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# craete data
X, y = make_regression(n_samples=1000, n_features=2, noise=10, random_state=42)


# train split 
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# craete model
regressor=KNeighborsRegressor(n_neighbors=6,algorithm='auto')
regressor.fit(X_train,y_train)

#predict
y_pred=regressor.predict(X_test)

# metrics
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.9189275159979495
# 9.009462452972217
# 127.45860414317289
