# %% [markdown]
# Ensemble in Machine Learning (Short Interview Note)
#
# Ensemble Learning is a technique in machine learning where multiple models (called base learners) are combined to produce a better and more robust prediction than a single model.
#
# Idea:
# Instead of relying on one model, ensemble methods aggregate predictions from several models to improve accuracy, reduce overfitting, and increase stability.
#
# Simple Example:
# If several models vote on a prediction, the final output may be decided by majority voting or averaging.
#
# # Models:-  we use different model.
# # data for all model:- we use same data.
# # voting type:- hard/soft/weighted
# # result:- for clasifier majroty voting and regression mean for all predicted .
#
#
# Types of Ensemble Methods
#
# 1.Bagging (Bootstrap Aggregating)
#
#     Trains multiple models independently using different random samples of the dataset.
#
#     Final prediction is usually averaging (regression) or majority vote (classification).
#
#     Helps reduce variance.
#
#     Example: Random Forest.
#
# 2. Boosting
#
#     Models are trained sequentially, where each new model focuses on correcting errors of previous models.
#
#     Helps reduce bias and variance.
#
#     Examples:
#
#     AdaBoost
#
#     Gradient Boosting
#
#     XGBoost.
#
# 3. Stacking (Stacked Generalization)
#
#     Combines predictions from multiple different models.
#
#     A meta-model learns how to best combine their outputs.
#
#
# ✅ Why use Ensemble Methods?
#
#     Higher prediction accuracy
#
#     Reduces overfitting
#
#     Improves model robustness

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load dataset
X, y = load_iris(return_X_y=True)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Base models
# Models:-  we use different model.
# data for all model:- we use same data.
# voting type:- hard/soft
# result:- for clasifier majroty voting
model1 = LogisticRegression()
model2 = DecisionTreeClassifier()
model3 = KNeighborsClassifier()

# Voting classifier
voting_model = VotingClassifier(
    estimators=[
        ('lr', model1),
        ('dt', model2),
        ('knn', model3)
    ],
    voting='hard'   # majority voting
)

# Train
voting_model.fit(X_train, y_train)

# Predict
y_pred = voting_model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# if we use single model it will give less accuracy then multiple model.
# Out:
# Accuracy: 0.9333333333333333
